# %% [markdown]
# ## **Denoising Diffusion Implicit Models (DDIM)**

# %% [markdown]
# Papers:
# - https://arxiv.org/abs/2010.02502
#
# Helpful resources:
# - https://learnopencv.com/understanding-ddim/
# - https://github.com/ermongroup/ddim
