# %% [markdown]
# ## **Conservative Q-Learning (CQL)**

# %% [markdown]
# References:
# - [Conservative Q-Learning for Offline Reinforcement Learning - A Kumar](https://arxiv.org/pdf/2006.04779)
# - [CQL github implementation - BY571](https://github.com/BY571/CQL)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm

print("imports done!")
# Out:
# imports done!

# %% [markdown]
# ### **CQL: Theory**
#
# **Write the algorithm theory here**
